# %% [markdown]
# # Mini Proyecto: Sistema de Sentiment Analysis con NLP
#
# Materia: Minería de Datos y Ciencia de Datos
#
# Este notebook ejecuta el pipeline completo del proyecto: carga de datos, preprocesamiento NLP, BoW, TF-IDF, entrenamiento de modelos y evaluación.

# %% [markdown]
# ## 1. Instalación de dependencias
# Ejecuta esta celda en Colab si el ambiente no tiene las librerías instaladas.

# %%
# En Google Colab, descomenta esta línea:
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Importación del pipeline

# %%
from pathlib import Path
import pandas as pd
from src.main import run_experiment
from src.config import DATA_SAMPLE

# %% [markdown]
# ## 3. Ejecución con dataset de muestra
# El dataset de muestra permite validar que todo el código corre antes de usar Kaggle.

# %%
results_df = run_experiment(DATA_SAMPLE)
results_df.head(12)

# %% [markdown]
# ## 4. Ejecución con dataset real de Kaggle
# Coloca el archivo real en `data/raw/kindle_reviews.csv` y ejecuta la siguiente celda.

# %%
# DATA_REAL = Path('data/raw/kindle_reviews.csv')
# results_real = run_experiment(DATA_REAL)
# results_real.head(12)

# %% [markdown]
# ## 5. Clasificación de una reseña nueva

# %%
from src.predict import predict_sentiment

texto = 'This Kindle book was excellent and very enjoyable'
predict_sentiment(texto, DATA_SAMPLE)
